# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51844/ADM/blob/main/ASS3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
data = pd.read_csv("employee_performance.csv")

# Standardize the data
scaler = StandardScaler()
data_scaled = scaler.fit_transform(data)
#performance PCA
pca = PCA(n_components=2)
principal_components = pca.fit_transform(data_scaled)
#to convert into dataframe
df=pd.DataFrame(data=principal_components,columns=['PC1','PC2'])
df
#to plat scatter plot
plt.figure(figsize=(10, 10))
plt.scatter(df['PC1'], df['PC2'])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Performance PCA')
plt.grid()
plt.show()
